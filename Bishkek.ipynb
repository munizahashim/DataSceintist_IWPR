# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the data from Excel
data = pd.read_excel("C:/Users/UCA/Documents/summers 2023/IWPR internship/building/Final Project/Bishkek_data.xlsx")

# Create a figure and a 3D subplot
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

# Set positions and dimensions for bars
xpos = np.arange(len(data))
ypos = data['No. of Buildings']
zpos = np.zeros(len(data))
dx = np.full(len(data), 0.8)  # Length of the bars (adjust this value to change the distance)
dy = np.full(len(data), 5000)  # Width of the bars
dz = data['No. of Floors']

# Define a color map and normalize the number of floors to map to colors
light_blue = (0, 93, 138)   # (R, G, B) for light blue
color = (light_blue[0] / 255, light_blue[1] / 255, light_blue[2] / 255)  # Normalize RGB values to be in the range [0, 1]


# Plot the 3D bar graph with varying intensity of blue along the height of each bar
for i, (x, y, z, h) in enumerate(zip(xpos, ypos, zpos, dz)):
    intensity = np.linspace(0.2, 1, h)  # Adjust intensity along the height of the bar
    for j in range(h):
        if j >= 5:  # Start using blue color after the 5th floor
            blue_intensity = intensity[j]
        else:
            blue_intensity = 0  # Keep the bottom part white
        bar_color = (
            (1 - blue_intensity) * color[0], 
            (1 - blue_intensity) * color[1], 
            (1 - blue_intensity) * color[2], 
            1.0  # Alpha value (fully opaque)
        )
        ax1.bar3d(x, y, z+j, dx[i], dy[i], 1, color=bar_color)

        
# Add a title to the figure
fig.suptitle('Bishkek')
        
        
# Set labels for the axes
ax1.set_xlabel('Bishkek')
ax1.set_ylabel('No. of Buildings')
ax1.set_zlabel('No. of Floors')

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
data.head(22)
# Out:
#        City  No. of Floors  No. of Buildings
# 0   Bishkek             12               107
# 1   Bishkek              1            102218
# 2   Bishkek              3               308
# 3   Bishkek              2              4154
# 4   Bishkek              8                17
# 5   Bishkek              7                35
# 6   Bishkek              9               545
# 7   Bishkek              6                56
# 8   Bishkek              5               495
# 9   Bishkek              4               336
# 10  Bishkek             14                11
# 11  Bishkek             10               109
# 12  Bishkek             16                 7
# 13  Bishkek             13                16
# 14  Bishkek             18                 8
# 15  Bishkek             11                20
# 16  Bishkek              0                 3
# 17  Bishkek             17                 3
# 18  Bishkek             37                 1
# 19  Bishkek             33                 1

# %%
data.head()
# Out:
#       City  No. of Floors  No. of Buildings
# 0  Bishkek             12               107
# 1  Bishkek              1            102218
# 2  Bishkek              3               308
# 3  Bishkek              2              4154
# 4  Bishkek              8                17

# %%
import matplotlib.pyplot as plt
import mplcursors
import numpy as np
import pandas as pd

# Load the data from Excel
data = pd.read_excel("C:/Users/UCA/Documents/summers 2023/IWPR internship/building/Final Project/Bishkek_data.xlsx")

# Create a figure and a 3D subplot
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

# Set positions and dimensions for bars
xpos = np.arange(len(data))
ypos = data['No. of Buildings']
zpos = np.zeros(len(data))
dx = np.full(len(data), 0.8)  # Length of the bars (adjust this value to change the distance)
dy = np.full(len(data), 5000)  # Width of the bars
dz = data['No. of Floors']

# Define a color map and normalize the number of floors to map to colors
light_blue = (0, 93, 138)
color = (light_blue[0] / 255, light_blue[1] / 255, light_blue[2] / 255)

# Plot the 3D bar graph with varying intensity of blue along the height of each bar
for i, (x, y, z, h) in enumerate(zip(xpos, ypos, zpos, dz)):
    intensity = np.linspace(0.2, 1, h)
    for j in range(h):
        if j >= 5:
            blue_intensity = intensity[j]
        else:
            blue_intensity = 0
        bar_color = (
            (1 - blue_intensity) * color[0], 
            (1 - blue_intensity) * color[1], 
            (1 - blue_intensity) * color[2], 
            1.0
        )
        ax1.bar3d(x, y, z+j, dx[i], dy[i], 1, color=bar_color)

# Set labels for the axes
ax1.set_xlabel('Bishkek')
ax1.set_ylabel('No. of Buildings')
ax1.set_zlabel('No. of Floors')

# Add tooltips using mplcursors
cursor = mplcursors.cursor(hover=True)
cursor.connect("add", lambda sel: sel.annotation.set_text(f"Building: {sel.target[1]}\nFloors: {dz[sel.index]}"))

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# !pip install dash dash-bootstrap-components
# Out:
# Requirement already satisfied: dash in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (2.11.1)
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-1.4.2-py3-none-any.whl (220 kB)
#                                               0.0/220.6 kB ? eta -:--:--
#      -                                        10.2/220.6 kB ? eta -:--:--
#      -----                                 30.7/220.6 kB 445.2 kB/s eta 0:00:01
#      ------                                41.0/220.6 kB 281.8 kB/s eta 0:00:01
#      ---------------                       92.2/220.6 kB 479.1 kB/s eta 0:00:01
#      ---------------                       92.2/220.6 kB 479.1 kB/s eta 0:00:01
#      -----------------------              143.4/220.6 kB 502.3 kB/s eta 0:00:01
#      -------------------------            153.6/220.6 kB 484.3 kB/s eta 0:00:01
#      -------------------------------      194.6/220.6 kB 513.4 kB/s eta 0:00:01
#      -----------------------------------  215.0/220.6 kB 504.4 kB/s eta 0:00:01
#      ------------------------------------ 220.6/220.6 kB 499.8 kB/s eta 0:00:00
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (5.11.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (4.4.0)
# Requirement already satisfied: requests in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.28.1)
# Requirement already satisfied: retrying in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\uca\appdata\roaming\python\python310\site-packages (from dash) (1.5.6)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.0.0->dash) (8.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from Werkzeug<2.3.0->dash) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from requests->dash) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from requests->dash) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uca\appdata\local\programs\python\python310\lib\site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: six>=1.7.0 in c:\users\uca\appdata\roaming\python\python310\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\uca\appdata\roaming\python\python310\site-packages (from click>=8.0->Flask<2.3.0,>=1.0.4->dash) (0.4.6)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-1.4.2
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
import base64

# Load the data from Excel
data = pd.read_excel("C:/Users/UCA/Documents/summers 2023/IWPR internship/building/Final Project/Bishkek_data.xlsx")

# Create a figure and a 3D subplot
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

# Set positions and dimensions for bars
xpos = np.arange(len(data))
ypos = data['No. of Buildings']
zpos = np.zeros(len(data))
dx = np.full(len(data), 0.8)  # Length of the bars (adjust this value to change the distance)
dy = np.full(len(data), 5000)  # Width of the bars
dz = data['No. of Floors']

# Define a color map and normalize the number of floors to map to colors
light_blue = (0, 93, 138)   # (R, G, B) for light blue
color = (light_blue[0] / 255, light_blue[1] / 255, light_blue[2] / 255)  # Normalize RGB values to be in the range [0, 1]

# Plot the 3D bar graph with varying intensity of blue along the height of each bar
for i, (x, y, z, h) in enumerate(zip(xpos, ypos, zpos, dz)):
    intensity = np.linspace(0.2, 1, h)  # Adjust intensity along the height of the bar
    for j in range(h):
        if j >= 5:  # Start using blue color after the 5th floor
            blue_intensity = intensity[j]
        else:
            blue_intensity = 0  # Keep the bottom part white
        bar_color = (
            (1 - blue_intensity) * color[0], 
            (1 - blue_intensity) * color[1], 
            (1 - blue_intensity) * color[2], 
            1.0  # Alpha value (fully opaque)
        )
        ax1.bar3d(x, y, z+j, dx[i], dy[i], 1, color=bar_color)

# Add a title to the figure
fig.suptitle('Bishkek')

# Set labels for the axes
ax1.set_xlabel('Bishkek')
ax1.set_ylabel('No. of Buildings')
ax1.set_zlabel('No. of Floors')

# Create a Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    dcc.Graph(figure=fig, id='3d-graph'),
])

if __name__ == '__main__':
    app.run_server(debug=True, port = 4055)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:4055/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Out:
#   Cell In[6], line 10
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 8
